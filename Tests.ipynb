# %%
from model.main import MainData
import pandas as pd

# MainData.test_create_model()
race_id = 202105040502
# df = MainData.scrape_pred(race_id)
# print(df)
all_data = MainData.test_get_data()
all_data
# pred = MainData.predict(race_id)
# print(pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_24745/2920766583.py in <module>
#       6 # df = MainData.scrape_pred(race_id)
#       7 # print(df)
# ----> 8 all_data = MainData.test_get_data()
#       9 all_data
#      10 # pred = MainData.predict(race_id)
#
# AttributeError: type object 'MainData' has no attribute 'test_get_data'

# %%
import json

# %%
# Out:
# {'race_data': [{'Hor_Num': 6,
#    'Hor_name': 'ウインルーア',
#    'Hor_sex_and_age': '牝2',
#    'Horse_weight': 438,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': '横山武',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 16.0,
#    'Popularity': 3,
#    'Race_Name': '2歳未勝利',
#    'Race_Time': 109.7,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010101,
#    'Ranking': 1,
#    'Trainer_1': '美浦',
#    'Trainer_2': '青木',
#    'Uni_Num': 6,
#    'ato_3_F': 35.6,
#    'competition_count': 1,
#    'corner_rank_1': 5.0,
#    'corner_rank_2': 5.0,
#    'corner_rank_3': 3.0,
#    'corner_rank_4': 3.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1800,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 6,
#    'race_type': '[指]',
#    'start_time': 955,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 2,
#    'Hor_name': 'アークライト',
#    'Hor_sex_and_age': '牡2',
#    'Horse_weight': 510,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': 'ルメー',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 1.9,
#    'Popularity': 2,
#    'Race_Name': '2歳未勝利',
#    'Race_Time': 110.0,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010101,
#    'Ranking': 2,
#    'Trainer_1': '美浦',
#    'Trainer_2': '藤沢和',
#    'Uni_Num': 2,
#    'ato_3_F': 35.8,
#    'competition_count': 1,
#    'corner_rank_1': 3.0,
#    'corner_rank_2': 3.0,
#    'corner_rank_3': 4.0,
#    'corner_rank_4': 3.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1800,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 6,
#    'race_type': '[指]',
#    'start_time': 955,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 3,
#    'Hor_name': 'ギャラントウォリア',
#    'Hor_sex_and_age': '牡2',
#    'Horse_weight': 482,
#    'Horse_weight_Flux': -6.0,
#    'Jockey': '池添',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 1.8,
#    'Popularity': 1,
#    'Race_Name': '2歳未勝利',
#    'Race_Time': 110.1,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010101,
#    'Ranking': 3,
#    'Trainer_1': '栗東',
#    'Trainer_2': '平田',
#    'Uni_Num': 3,
#    'ato_3_F': 36.2,
#    'competition_count': 1,
#    'corner_rank_1': 2.0,
#    'corner_rank_2': 2.0,
#    'corner_rank_3': 2.0,
#    'corner_rank_4': 2.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1800,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 6,
#    'race_type': '[指]',
#    'start_time': 955,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 1,
#    'Hor_name': 'ジュンブーケ',
#    'Hor_sex_and_age': '牝2',
#    'Horse_weight': 442,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '亀田',
#    'JockeyWeight': 52.0,
#    'Odds_popularity': 22.2,
#    'Popularity': 4,
#    'Race_Name': '2歳未勝利',
#    'Race_Time': 110.5,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010101,
#    'Ranking': 4,
#    'Trainer_1': '栗東',
#    'Trainer_2': '森',
#    'Uni_Num': 1,
#    'ato_3_F': 36.7,
#    'competition_count': 1,
#    'corner_rank_1': 1.0,
#    'corner_rank_2': 1.0,
#    'corner_rank_3': 1.0,
#    'corner_rank_4': 1.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1800,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 6,
#    'race_type': '[指]',
#    'start_time': 955,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 4,
#    'Hor_name': 'キタノマンゲツ',
#    'Hor_sex_and_age': '牡2',
#    'Horse_weight': 426,
#    'Horse_weight_Flux': -8.0,
#    'Jockey': '藤岡康',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 55.7,
#    'Popularity': 5,
#    'Race_Name': '2歳未勝利',
#    'Race_Time': 111.0,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010101,
#    'Ranking': 5,
#    'Trainer_1': '栗東',
#    'Trainer_2': '中尾',
#    'Uni_Num': 4,
#    'ato_3_F': 36.6,
#    'competition_count': 1,
#    'corner_rank_1': 6.0,
#    'corner_rank_2': 6.0,
#    'corner_rank_3': 5.0,
#    'corner_rank_4': 5.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1800,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 6,
#    'race_type': '[指]',
#    'start_time': 955,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 5,
#    'Hor_name': 'アイフレンズ',
#    'Hor_sex_and_age': '牝2',
#    'Horse_weight': 426,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '黛',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 73.9,
#    'Popularity': 6,
#    'Race_Name': '2歳未勝利',
#    'Race_Time': 112.7,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010101,
#    'Ranking': 6,
#    'Trainer_1': '美浦',
#    'Trainer_2': '中野',
#    'Uni_Num': 5,
#    'ato_3_F': 38.0,
#    'competition_count': 1,
#    'corner_rank_1': 3.0,
#    'corner_rank_2': 3.0,
#    'corner_rank_3': 6.0,
#    'corner_rank_4': 6.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1800,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 6,
#    'race_type': '[指]',
#    'start_time': 955,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 4,
#    'Hor_name': 'バトルピアサー',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 406,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '川島',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 2.7,
#    'Popularity': 1,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.2,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 1,
#    'Trainer_1': '栗東',
#    'Trainer_2': '荒川',
#    'Uni_Num': 3,
#    'ato_3_F': 39.0,
#    'competition_count': 1,
#    'corner_rank_1': 1.0,
#    'corner_rank_2': 1.0,
#    'corner_rank_3': 1.0,
#    'corner_rank_4': 1.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 14,
#    'Hor_name': 'バーミーズ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 456,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '丹内',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 6.3,
#    'Popularity': 3,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.9,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 2,
#    'Trainer_1': '栗東',
#    'Trainer_2': '飯田雄',
#    'Uni_Num': 8,
#    'ato_3_F': 39.6,
#    'competition_count': 1,
#    'corner_rank_1': 3.0,
#    'corner_rank_2': 2.0,
#    'corner_rank_3': 2.0,
#    'corner_rank_4': 2.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 13,
#    'Hor_name': 'ノーブルローズ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 446,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '大野',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 19.1,
#    'Popularity': 8,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.0,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 3,
#    'Trainer_1': '美浦',
#    'Trainer_2': '高柳瑞',
#    'Uni_Num': 8,
#    'ato_3_F': 38.8,
#    'competition_count': 1,
#    'corner_rank_1': 14.0,
#    'corner_rank_2': 14.0,
#    'corner_rank_3': 11.0,
#    'corner_rank_4': 5.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 6,
#    'Hor_name': 'グッドラックスター',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 434,
#    'Horse_weight_Flux': -6.0,
#    'Jockey': '荻野琢',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 3.9,
#    'Popularity': 2,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.1,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 4,
#    'Trainer_1': '栗東',
#    'Trainer_2': '野中',
#    'Uni_Num': 4,
#    'ato_3_F': 39.1,
#    'competition_count': 1,
#    'corner_rank_1': 5.0,
#    'corner_rank_2': 5.0,
#    'corner_rank_3': 8.0,
#    'corner_rank_4': 8.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 3,
#    'Hor_name': 'デルマルビー',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 462,
#    'Horse_weight_Flux': -4.0,
#    'Jockey': '横山和',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 16.8,
#    'Popularity': 6,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 5,
#    'Trainer_1': '栗東',
#    'Trainer_2': '千田',
#    'Uni_Num': 3,
#    'ato_3_F': 39.2,
#    'competition_count': 1,
#    'corner_rank_1': 8.0,
#    'corner_rank_2': 11.0,
#    'corner_rank_3': 10.0,
#    'corner_rank_4': 3.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 12,
#    'Hor_name': 'アマデトワール',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 446,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': '藤岡康',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 15.9,
#    'Popularity': 5,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.8,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 6,
#    'Trainer_1': '栗東',
#    'Trainer_2': '高橋康',
#    'Uni_Num': 7,
#    'ato_3_F': 39.6,
#    'competition_count': 1,
#    'corner_rank_1': 8.0,
#    'corner_rank_2': 8.0,
#    'corner_rank_3': 11.0,
#    'corner_rank_4': 10.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 9,
#    'Hor_name': 'ミツルザビクトリー',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 438,
#    'Horse_weight_Flux': -4.0,
#    'Jockey': '亀田',
#    'JockeyWeight': 52.0,
#    'Odds_popularity': 56.1,
#    'Popularity': 12,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.0,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 7,
#    'Trainer_1': '栗東',
#    'Trainer_2': '南井',
#    'Uni_Num': 6,
#    'ato_3_F': 39.5,
#    'competition_count': 1,
#    'corner_rank_1': 12.0,
#    'corner_rank_2': 12.0,
#    'corner_rank_3': 14.0,
#    'corner_rank_4': 10.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 8,
#    'Hor_name': 'キモンルビー',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 462,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '山田',
#    'JockeyWeight': 51.0,
#    'Odds_popularity': 41.8,
#    'Popularity': 11,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.0,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 8,
#    'Trainer_1': '栗東',
#    'Trainer_2': '村山',
#    'Uni_Num': 5,
#    'ato_3_F': 40.7,
#    'competition_count': 1,
#    'corner_rank_1': 2.0,
#    'corner_rank_2': 2.0,
#    'corner_rank_3': 2.0,
#    'corner_rank_4': 5.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 1,
#    'Hor_name': 'ムーンフェアリー',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 450,
#    'Horse_weight_Flux': 6.0,
#    'Jockey': '秋山稔',
#    'JockeyWeight': 51.0,
#    'Odds_popularity': 22.3,
#    'Popularity': 9,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.1,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 9,
#    'Trainer_1': '美浦',
#    'Trainer_2': '岩戸',
#    'Uni_Num': 1,
#    'ato_3_F': 40.2,
#    'competition_count': 1,
#    'corner_rank_1': 8.0,
#    'corner_rank_2': 8.0,
#    'corner_rank_3': 8.0,
#    'corner_rank_4': 10.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 5,
#    'Hor_name': 'シゲルハクチョウザ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 444,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '加藤',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 25.4,
#    'Popularity': 10,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.2,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 10,
#    'Trainer_1': '栗東',
#    'Trainer_2': '藤沢則',
#    'Uni_Num': 4,
#    'ato_3_F': 40.7,
#    'competition_count': 1,
#    'corner_rank_1': 4.0,
#    'corner_rank_2': 4.0,
#    'corner_rank_3': 4.0,
#    'corner_rank_4': 4.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 10,
#    'Hor_name': 'フェデネージュ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 444,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': '岩田康',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 18.6,
#    'Popularity': 7,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.4,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 11,
#    'Trainer_1': '美浦',
#    'Trainer_2': '国枝',
#    'Uni_Num': 6,
#    'ato_3_F': 40.6,
#    'competition_count': 1,
#    'corner_rank_1': 13.0,
#    'corner_rank_2': 13.0,
#    'corner_rank_3': 7.0,
#    'corner_rank_4': 5.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 2,
#    'Hor_name': 'ラインキャロット',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 430,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': '石川',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 133.5,
#    'Popularity': 14,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.9,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 12,
#    'Trainer_1': '美浦',
#    'Trainer_2': '水野',
#    'Uni_Num': 2,
#    'ato_3_F': 40.6,
#    'competition_count': 1,
#    'corner_rank_1': 8.0,
#    'corner_rank_2': 8.0,
#    'corner_rank_3': 11.0,
#    'corner_rank_4': 13.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 11,
#    'Hor_name': 'サイモンベラーノ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 476,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': '柴山',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 9.3,
#    'Popularity': 4,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 109.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 13,
#    'Trainer_1': '美浦',
#    'Trainer_2': '根本',
#    'Uni_Num': 7,
#    'ato_3_F': 41.6,
#    'competition_count': 1,
#    'corner_rank_1': 5.0,
#    'corner_rank_2': 5.0,
#    'corner_rank_3': 5.0,
#    'corner_rank_4': 8.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 7,
#    'Hor_name': 'クイックスタディ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 462,
#    'Horse_weight_Flux': -8.0,
#    'Jockey': '団野',
#    'JockeyWeight': 53.0,
#    'Odds_popularity': 120.9,
#    'Popularity': 13,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 110.9,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010102,
#    'Ranking': 14,
#    'Trainer_1': '美浦',
#    'Trainer_2': '矢野',
#    'Uni_Num': 5,
#    'ato_3_F': 43.2,
#    'competition_count': 1,
#    'corner_rank_1': 5.0,
#    'corner_rank_2': 5.0,
#    'corner_rank_3': 5.0,
#    'corner_rank_4': 13.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '牝[指]',
#    'start_time': 1025,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 2,
#    'Hor_name': 'フリークアウト',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 448,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '藤岡佑',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 2.9,
#    'Popularity': 2,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 88.5,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 1,
#    'Trainer_1': '栗東',
#    'Trainer_2': '中内田',
#    'Uni_Num': 2,
#    'ato_3_F': 35.0,
#    'competition_count': 1,
#    'corner_rank_1': 3.0,
#    'corner_rank_2': 2.0,
#    'corner_rank_3': 4.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 6,
#    'Hor_name': 'クァンタムリープ',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 474,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': 'ルメー',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 2.3,
#    'Popularity': 1,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 88.8,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 2,
#    'Trainer_1': '美浦',
#    'Trainer_2': '鹿戸',
#    'Uni_Num': 4,
#    'ato_3_F': 35.4,
#    'competition_count': 1,
#    'corner_rank_1': 2.0,
#    'corner_rank_2': 2.0,
#    'corner_rank_3': 2.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 12,
#    'Hor_name': 'クレアーレ',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 448,
#    'Horse_weight_Flux': -12.0,
#    'Jockey': '亀田',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 25.0,
#    'Popularity': 7,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 88.8,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 3,
#    'Trainer_1': '栗東',
#    'Trainer_2': '池江',
#    'Uni_Num': 7,
#    'ato_3_F': 34.8,
#    'competition_count': 1,
#    'corner_rank_1': 9.0,
#    'corner_rank_2': 9.0,
#    'corner_rank_3': 9.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 4,
#    'Hor_name': 'タツハグンセイ',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 464,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': '古川',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 12.9,
#    'Popularity': 5,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 89.0,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 4,
#    'Trainer_1': '栗東',
#    'Trainer_2': '鮫島',
#    'Uni_Num': 3,
#    'ato_3_F': 35.8,
#    'competition_count': 1,
#    'corner_rank_1': 1.0,
#    'corner_rank_2': 1.0,
#    'corner_rank_3': 1.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 11,
#    'Hor_name': 'ラブアンバサダー',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 430,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '武豊',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 7.4,
#    'Popularity': 3,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 89.1,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 5,
#    'Trainer_1': '栗東',
#    'Trainer_2': '松永幹',
#    'Uni_Num': 7,
#    'ato_3_F': 34.9,
#    'competition_count': 1,
#    'corner_rank_1': 11.0,
#    'corner_rank_2': 12.0,
#    'corner_rank_3': 9.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 14,
#    'Hor_name': 'ルーターズ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 402,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '藤岡康',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 10.3,
#    'Popularity': 4,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 89.1,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 6,
#    'Trainer_1': '栗東',
#    'Trainer_2': '宮',
#    'Uni_Num': 8,
#    'ato_3_F': 35.4,
#    'competition_count': 1,
#    'corner_rank_1': 6.0,
#    'corner_rank_2': 5.0,
#    'corner_rank_3': 5.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 8,
#    'Hor_name': 'レッドキュリアス',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 422,
#    'Horse_weight_Flux': -4.0,
#    'Jockey': '横山武',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 89.8,
#    'Popularity': 10,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 89.1,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 7,
#    'Trainer_1': '栗東',
#    'Trainer_2': '松永幹',
#    'Uni_Num': 5,
#    'ato_3_F': 35.2,
#    'competition_count': 1,
#    'corner_rank_1': 8.0,
#    'corner_rank_2': 8.0,
#    'corner_rank_3': 7.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 3,
#    'Hor_name': 'ミッキーローズ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 406,
#    'Horse_weight_Flux': -10.0,
#    'Jockey': '団野',
#    'JockeyWeight': 53.0,
#    'Odds_popularity': 85.8,
#    'Popularity': 9,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 89.2,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 8,
#    'Trainer_1': '栗東',
#    'Trainer_2': '池江',
#    'Uni_Num': 3,
#    'ato_3_F': 35.5,
#    'competition_count': 1,
#    'corner_rank_1': 6.0,
#    'corner_rank_2': 5.0,
#    'corner_rank_3': 7.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 13,
#    'Hor_name': 'ブライドグルーム',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 448,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': '浜中',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 25.6,
#    'Popularity': 8,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 89.2,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 8,
#    'Trainer_1': '美浦',
#    'Trainer_2': '堀',
#    'Uni_Num': 8,
#    'ato_3_F': 35.8,
#    'competition_count': 1,
#    'corner_rank_1': 3.0,
#    'corner_rank_2': 2.0,
#    'corner_rank_3': 2.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 9,
#    'Hor_name': 'エンジェルエナ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 426,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '池添',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 90.1,
#    'Popularity': 11,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 89.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 10,
#    'Trainer_1': '美浦',
#    'Trainer_2': '大竹',
#    'Uni_Num': 6,
#    'ato_3_F': 35.2,
#    'competition_count': 1,
#    'corner_rank_1': 9.0,
#    'corner_rank_2': 10.0,
#    'corner_rank_3': 9.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 10,
#    'Hor_name': 'ミルキーハート',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 448,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '丹内',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 23.8,
#    'Popularity': 6,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 89.4,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 11,
#    'Trainer_1': '美浦',
#    'Trainer_2': '牧',
#    'Uni_Num': 6,
#    'ato_3_F': 35.8,
#    'competition_count': 1,
#    'corner_rank_1': 5.0,
#    'corner_rank_2': 5.0,
#    'corner_rank_3': 5.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 5,
#    'Hor_name': 'アンネローゼ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 444,
#    'Horse_weight_Flux': -6.0,
#    'Jockey': '荻野琢',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 211.3,
#    'Popularity': 13,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 89.9,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 12,
#    'Trainer_1': '美浦',
#    'Trainer_2': '大和田',
#    'Uni_Num': 4,
#    'ato_3_F': 35.5,
#    'competition_count': 1,
#    'corner_rank_1': 13.0,
#    'corner_rank_2': 13.0,
#    'corner_rank_3': 13.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 1,
#    'Hor_name': 'ステーションワン',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 456,
#    'Horse_weight_Flux': -6.0,
#    'Jockey': '国分恭',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 239.1,
#    'Popularity': 14,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 90.5,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 13,
#    'Trainer_1': '栗東',
#    'Trainer_2': '牧田',
#    'Uni_Num': 1,
#    'ato_3_F': 36.4,
#    'competition_count': 1,
#    'corner_rank_1': 11.0,
#    'corner_rank_2': 10.0,
#    'corner_rank_3': 9.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 7,
#    'Hor_name': 'カドーダンジュ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 456,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '大野',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 116.7,
#    'Popularity': 12,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 110.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010103,
#    'Ranking': 14,
#    'Trainer_1': '美浦',
#    'Trainer_2': '久保田',
#    'Uni_Num': 5,
#    'ato_3_F': 49.0,
#    'competition_count': 1,
#    'corner_rank_1': 14.0,
#    'corner_rank_2': 14.0,
#    'corner_rank_3': 14.0,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 13,
#    'Hor_name': 'エンペラーズパレス',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 492,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '水口',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 42.2,
#    'Popularity': 10,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 1,
#    'Trainer_1': '栗東',
#    'Trainer_2': '羽月',
#    'Uni_Num': 8,
#    'ato_3_F': 38.2,
#    'competition_count': 1,
#    'corner_rank_1': 1.0,
#    'corner_rank_2': 1.0,
#    'corner_rank_3': 1.0,
#    'corner_rank_4': 1.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 2,
#    'Hor_name': 'マイネルパイオニア',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 462,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '横山武',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 4.6,
#    'Popularity': 2,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.6,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 2,
#    'Trainer_1': '美浦',
#    'Trainer_2': '中舘',
#    'Uni_Num': 2,
#    'ato_3_F': 38.1,
#    'competition_count': 1,
#    'corner_rank_1': 2.0,
#    'corner_rank_2': 3.0,
#    'corner_rank_3': 3.0,
#    'corner_rank_4': 2.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 10,
#    'Hor_name': 'ウォータージョイ',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 476,
#    'Horse_weight_Flux': -6.0,
#    'Jockey': '国分恭',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 37.1,
#    'Popularity': 9,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.8,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 3,
#    'Trainer_1': '栗東',
#    'Trainer_2': '岡田',
#    'Uni_Num': 6,
#    'ato_3_F': 38.0,
#    'competition_count': 1,
#    'corner_rank_1': 9.0,
#    'corner_rank_2': 7.0,
#    'corner_rank_3': 6.0,
#    'corner_rank_4': 6.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 7,
#    'Hor_name': 'モズナガレボシ',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 488,
#    'Horse_weight_Flux': 6.0,
#    'Jockey': '大野',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 5.2,
#    'Popularity': 4,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.9,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 4,
#    'Trainer_1': '栗東',
#    'Trainer_2': '荒川',
#    'Uni_Num': 5,
#    'ato_3_F': 38.3,
#    'competition_count': 1,
#    'corner_rank_1': 4.0,
#    'corner_rank_2': 3.0,
#    'corner_rank_3': 3.0,
#    'corner_rank_4': 4.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 3,
#    'Hor_name': 'サウンドトラック',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 508,
#    'Horse_weight_Flux': 10.0,
#    'Jockey': 'ルメー',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 3.3,
#    'Popularity': 1,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.9,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 5,
#    'Trainer_1': '美浦',
#    'Trainer_2': '尾関',
#    'Uni_Num': 3,
#    'ato_3_F': 38.1,
#    'competition_count': 1,
#    'corner_rank_1': 7.0,
#    'corner_rank_2': 7.0,
#    'corner_rank_3': 6.0,
#    'corner_rank_4': 6.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 12,
#    'Hor_name': 'シェノン',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 468,
#    'Horse_weight_Flux': 2.0,
#    'Jockey': '吉田隼',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 33.1,
#    'Popularity': 8,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.0,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 6,
#    'Trainer_1': '栗東',
#    'Trainer_2': '矢作',
#    'Uni_Num': 7,
#    'ato_3_F': 38.4,
#    'competition_count': 1,
#    'corner_rank_1': 6.0,
#    'corner_rank_2': 6.0,
#    'corner_rank_3': 3.0,
#    'corner_rank_4': 4.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 8,
#    'Hor_name': 'サイモンバトラー',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 458,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '黛',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 210.0,
#    'Popularity': 14,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.0,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 7,
#    'Trainer_1': '美浦',
#    'Trainer_2': '矢野',
#    'Uni_Num': 5,
#    'ato_3_F': 38.2,
#    'competition_count': 1,
#    'corner_rank_1': 7.0,
#    'corner_rank_2': 7.0,
#    'corner_rank_3': 6.0,
#    'corner_rank_4': 6.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 1,
#    'Hor_name': 'トクシーズファー',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 434,
#    'Horse_weight_Flux': 2.0,
#    'Jockey': '横山和',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 49.3,
#    'Popularity': 12,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.2,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 8,
#    'Trainer_1': '美浦',
#    'Trainer_2': '戸田',
#    'Uni_Num': 1,
#    'ato_3_F': 38.2,
#    'competition_count': 1,
#    'corner_rank_1': 11.0,
#    'corner_rank_2': 10.0,
#    'corner_rank_3': 10.0,
#    'corner_rank_4': 9.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 6,
#    'Hor_name': 'ウラワザテクニック',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 476,
#    'Horse_weight_Flux': 2.0,
#    'Jockey': '丹内',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 13.9,
#    'Popularity': 6,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 9,
#    'Trainer_1': '美浦',
#    'Trainer_2': '宗像',
#    'Uni_Num': 4,
#    'ato_3_F': 38.5,
#    'competition_count': 1,
#    'corner_rank_1': 4.0,
#    'corner_rank_2': 3.0,
#    'corner_rank_3': 6.0,
#    'corner_rank_4': 10.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 11,
#    'Hor_name': 'サーストンシカゴ',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 500,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '菱田',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 12.2,
#    'Popularity': 5,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.5,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 10,
#    'Trainer_1': '栗東',
#    'Trainer_2': '橋田',
#    'Uni_Num': 7,
#    'ato_3_F': 38.3,
#    'competition_count': 1,
#    'corner_rank_1': 9.0,
#    'corner_rank_2': 10.0,
#    'corner_rank_3': 11.0,
#    'corner_rank_4': 10.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 5,
#    'Hor_name': 'サクセスリバース',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 500,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '団野',
#    'JockeyWeight': 55.0,
#    'Odds_popularity': 44.9,
#    'Popularity': 11,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.5,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 11,
#    'Trainer_1': '美浦',
#    'Trainer_2': '中舘',
#    'Uni_Num': 4,
#    'ato_3_F': 38.2,
#    'competition_count': 1,
#    'corner_rank_1': 11.0,
#    'corner_rank_2': 14.0,
#    'corner_rank_3': 11.0,
#    'corner_rank_4': 10.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 4,
#    'Hor_name': 'エスポワールミノル',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 526,
#    'Horse_weight_Flux': 6.0,
#    'Jockey': '藤岡康',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 5.1,
#    'Popularity': 3,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.9,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 12,
#    'Trainer_1': '栗東',
#    'Trainer_2': '野中',
#    'Uni_Num': 3,
#    'ato_3_F': 39.5,
#    'competition_count': 1,
#    'corner_rank_1': 2.0,
#    'corner_rank_2': 2.0,
#    'corner_rank_3': 2.0,
#    'corner_rank_4': 2.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 9,
#    'Hor_name': 'ハラハラドキドキ',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 456,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': '亀田',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 16.7,
#    'Popularity': 7,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.2,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 13,
#    'Trainer_1': '美浦',
#    'Trainer_2': '久保田',
#    'Uni_Num': 6,
#    'ato_3_F': 38.9,
#    'competition_count': 1,
#    'corner_rank_1': 13.0,
#    'corner_rank_2': 10.0,
#    'corner_rank_3': 11.0,
#    'corner_rank_4': 13.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 14,
#    'Hor_name': 'カラヤン',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 470,
#    'Horse_weight_Flux': -6.0,
#    'Jockey': '秋山稔',
#    'JockeyWeight': 53.0,
#    'Odds_popularity': 138.4,
#    'Popularity': 13,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.5,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010104,
#    'Ranking': 14,
#    'Trainer_1': '美浦',
#    'Trainer_2': '小桧山',
#    'Uni_Num': 8,
#    'ato_3_F': 39.0,
#    'competition_count': 1,
#    'corner_rank_1': 13.0,
#    'corner_rank_2': 13.0,
#    'corner_rank_3': 14.0,
#    'corner_rank_4': 14.0,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 2,
#    'Hor_name': 'フクノラプラーニュ',
#    'Hor_sex_and_age': '牡2',
#    'Horse_weight': 478,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '横山和',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 15.9,
#    'Popularity': 4,
#    'Race_Name': '2歳新馬',
#    'Race_Time': 71.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010105,
#    'Ranking': 1,
#    'Trainer_1': '美浦',
#    'Trainer_2': '田島',
#    'Uni_Num': 2,
#    'ato_3_F': 35.3,
#    'competition_count': 1,
#    'corner_rank_1': 2.0,
#    'corner_rank_2': 2.0,
#    'corner_rank_3': None,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1200,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '新馬',
#    'number_of_hourses': 6,
#    'race_type': '(混)[指]',
#    'start_time': 1215,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '晴'},
#   {'Hor_Num': 5,
#    'Hor_name': 'スマートジュリアン',
#    'Hor_sex_and_age': '牝2',
#    'Horse_weight': 470,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '武豊',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 2.8,
#    'Popularity': 2,
#    'Race_Name': '2歳新馬',
#    'Race_Time': 71.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010105,
#    'Ranking': 2,
#    'Trainer_1': '栗東',
#    'Trainer_2': '浅見',
#    'Uni_Num': 5,
#    'ato_3_F': 35.7,
#    'competition_count': 1,
#    'corner_rank_1': 1.0,
#    'corner_rank_2': 1.0,
#    'corner_rank_3': None,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1200,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '新馬',
#    'number_of_hourses': 6,
#    'race_type': '(混)[指]',
#    'start_time': 1215,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '晴'},
#   {'Hor_Num': 1,
#    'Hor_name': 'ジオパークマグマ',
#    'Hor_sex_and_age': '牡2',
#    'Horse_weight': 434,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '柴山',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 27.3,
#    'Popularity': 6,
#    'Race_Name': '2歳新馬',
#    'Race_Time': 71.5,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010105,
#    'Ranking': 3,
#    'Trainer_1': '美浦',
#    'Trainer_2': '田中剛',
#    'Uni_Num': 1,
#    'ato_3_F': 35.3,
#    'competition_count': 1,
#    'corner_rank_1': 3.0,
#    'corner_rank_2': 4.0,
#    'corner_rank_3': None,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1200,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '新馬',
#    'number_of_hourses': 6,
#    'race_type': '(混)[指]',
#    'start_time': 1215,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '晴'},
#   {'Hor_Num': 4,
#    'Hor_name': 'レゼール',
#    'Hor_sex_and_age': '牝2',
#    'Horse_weight': 438,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': 'ルメー',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 1.7,
#    'Popularity': 1,
#    'Race_Name': '2歳新馬',
#    'Race_Time': 72.2,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010105,
#    'Ranking': 4,
#    'Trainer_1': '栗東',
#    'Trainer_2': '須貝',
#    'Uni_Num': 4,
#    'ato_3_F': 36.1,
#    'competition_count': 1,
#    'corner_rank_1': 3.0,
#    'corner_rank_2': 3.0,
#    'corner_rank_3': None,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1200,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '新馬',
#    'number_of_hourses': 6,
#    'race_type': '(混)[指]',
#    'start_time': 1215,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '晴'},
#   {'Hor_Num': 3,
#    'Hor_name': 'ネオペトリコール',
#    'Hor_sex_and_age': '牝2',
#    'Horse_weight': 402,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '秋山稔',
#    'JockeyWeight': 51.0,
#    'Odds_popularity': 17.2,
#    'Popularity': 5,
#    'Race_Name': '2歳新馬',
#    'Race_Time': 72.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010105,
#    'Ranking': 5,
#    'Trainer_1': '美浦',
#    'Trainer_2': '粕谷',
#    'Uni_Num': 3,
#    'ato_3_F': 35.8,
#    'competition_count': 1,
#    'corner_rank_1': 5.0,
#    'corner_rank_2': 5.0,
#    'corner_rank_3': None,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1200,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '新馬',
#    'number_of_hourses': 6,
#    'race_type': '(混)[指]',
#    'start_time': 1215,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '晴'},
#   {'Hor_Num': 6,
#    'Hor_name': 'ユイノザッパー',
#    'Hor_sex_and_age': '牡2',
#    'Horse_weight': 496,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '吉田隼',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 8.5,
#    'Popularity': 3,
#    'Race_Name': '2歳新馬',
#    'Race_Time': 72.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010105,
#    'Ranking': 6,
#    'Trainer_1': '栗東',
#    'Trainer_2': '矢作',
#    'Uni_Num': 6,
#    'ato_3_F': 35.2,
#    'competition_count': 1,
#    'corner_rank_1': 6.0,
#    'corner_rank_2': 6.0,
#    'corner_rank_3': None,
#    'corner_rank_4': None,
#    'day_count': 1,
#    'field_condition': '良',
#    'field_length': 1200,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系２歳',
#    'horse_class_2': '新馬',
#    'number_of_hourses': 6,
#    'race_type': '(混)[指]',
#    'start_time': 1215,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '晴'},
#   {'Hor_Num': 1,
#    'Hor_name': 'ユークレース',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 462,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '横山武',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 4.6,
#    'Popularity': 3,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 121.3,
#    'Race_date': 1595635200000.0,
#    'Race_id': 202001010106,
#    'Ranking': 1,
#    'Trainer_1': '美浦',
#    'Trainer_2': '菊沢',
#    'Uni_Num': 1,
#    'ato_3_F': 35.8,
#    'competition_count': 1,
#    'corner_rank_1': 1.0,
# ...
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 4,
#    'Hor_name': 'ロビンザフィリー',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 410,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': '石川',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 76.4,
#    'Popularity': 11,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 90.8,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020203,
#    'Ranking': 9,
#    'Trainer_1': '美浦',
#    'Trainer_2': '大和田',
#    'Uni_Num': 3,
#    'ato_3_F': 36.4,
#    'competition_count': 2,
#    'corner_rank_1': 1.0,
#    'corner_rank_2': 1.0,
#    'corner_rank_3': 1.0,
#    'corner_rank_4': None,
#    'day_count': 2,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 12,
#    'Hor_name': 'クリノサンシャイン',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 442,
#    'Horse_weight_Flux': 16.0,
#    'Jockey': '水口',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 13.4,
#    'Popularity': 5,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 90.8,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020203,
#    'Ranking': 10,
#    'Trainer_1': '栗東',
#    'Trainer_2': '高橋康',
#    'Uni_Num': 7,
#    'ato_3_F': 35.9,
#    'competition_count': 2,
#    'corner_rank_1': 3.0,
#    'corner_rank_2': 6.0,
#    'corner_rank_3': 6.0,
#    'corner_rank_4': None,
#    'day_count': 2,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 10,
#    'Hor_name': 'フジコウキ',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 452,
#    'Horse_weight_Flux': 8.0,
#    'Jockey': '秋山稔',
#    'JockeyWeight': 53.0,
#    'Odds_popularity': 14.5,
#    'Popularity': 7,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 90.8,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020203,
#    'Ranking': 11,
#    'Trainer_1': '美浦',
#    'Trainer_2': '大江原',
#    'Uni_Num': 6,
#    'ato_3_F': 36.4,
#    'competition_count': 2,
#    'corner_rank_1': 2.0,
#    'corner_rank_2': 2.0,
#    'corner_rank_3': 2.0,
#    'corner_rank_4': None,
#    'day_count': 2,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 11,
#    'Hor_name': 'ミツルグロウ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 426,
#    'Horse_weight_Flux': -4.0,
#    'Jockey': '松田',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 302.4,
#    'Popularity': 13,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 91.6,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020203,
#    'Ranking': 12,
#    'Trainer_1': '栗東',
#    'Trainer_2': '本田',
#    'Uni_Num': 7,
#    'ato_3_F': 36.6,
#    'competition_count': 2,
#    'corner_rank_1': 6.0,
#    'corner_rank_2': 6.0,
#    'corner_rank_3': 12.0,
#    'corner_rank_4': None,
#    'day_count': 2,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 13,
#    'Hor_name': 'ダンツシルビア',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 450,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '菱田',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 7.9,
#    'Popularity': 4,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 91.7,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020203,
#    'Ranking': 13,
#    'Trainer_1': '栗東',
#    'Trainer_2': '谷',
#    'Uni_Num': 8,
#    'ato_3_F': 36.8,
#    'competition_count': 2,
#    'corner_rank_1': 10.0,
#    'corner_rank_2': 6.0,
#    'corner_rank_3': 8.0,
#    'corner_rank_4': None,
#    'day_count': 2,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 7,
#    'Hor_name': 'ウメノハナ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 448,
#    'Horse_weight_Flux': -4.0,
#    'Jockey': '川島',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 163.7,
#    'Popularity': 12,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 91.9,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020203,
#    'Ranking': 14,
#    'Trainer_1': '美浦',
#    'Trainer_2': '小島',
#    'Uni_Num': 5,
#    'ato_3_F': 36.7,
#    'competition_count': 2,
#    'corner_rank_1': 8.0,
#    'corner_rank_2': 10.0,
#    'corner_rank_3': 14.0,
#    'corner_rank_4': None,
#    'day_count': 2,
#    'field_condition': '良',
#    'field_length': 1500,
#    'field_type_1': '芝',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '(混)[指]',
#    'start_time': 1055,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 12,
#    'Hor_name': 'ブラックトマホーク',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 476,
#    'Horse_weight_Flux': 4.0,
#    'Jockey': '横山武',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 4.5,
#    'Popularity': 2,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.4,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 1,
#    'Trainer_1': '美浦',
#    'Trainer_2': '高木',
#    'Uni_Num': 7,
#    'ato_3_F': 38.6,
#    'competition_count': 2,
#    'corner_rank_1': 8.0,
#    'corner_rank_2': 8.0,
#    'corner_rank_3': 6.0,
#    'corner_rank_4': 3.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 9,
#    'Hor_name': 'アバグネイル',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 532,
#    'Horse_weight_Flux': 8.0,
#    'Jockey': '石川',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 95.1,
#    'Popularity': 10,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.4,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 2,
#    'Trainer_1': '美浦',
#    'Trainer_2': '手塚',
#    'Uni_Num': 6,
#    'ato_3_F': 37.8,
#    'competition_count': 2,
#    'corner_rank_1': 13.0,
#    'corner_rank_2': 13.0,
#    'corner_rank_3': 11.0,
#    'corner_rank_4': 10.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 13,
#    'Hor_name': 'トクシーズファー',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 432,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '勝浦',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 76.1,
#    'Popularity': 9,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.4,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 3,
#    'Trainer_1': '美浦',
#    'Trainer_2': '戸田',
#    'Uni_Num': 8,
#    'ato_3_F': 38.1,
#    'competition_count': 2,
#    'corner_rank_1': 12.0,
#    'corner_rank_2': 11.0,
#    'corner_rank_3': 9.0,
#    'corner_rank_4': 8.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 0,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 2,
#    'Hor_name': 'オメガドラゴン',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 480,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': 'ルメー',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 2.0,
#    'Popularity': 1,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.5,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 4,
#    'Trainer_1': '栗東',
#    'Trainer_2': '安田翔',
#    'Uni_Num': 2,
#    'ato_3_F': 38.6,
#    'competition_count': 2,
#    'corner_rank_1': 8.0,
#    'corner_rank_2': 9.0,
#    'corner_rank_3': 6.0,
#    'corner_rank_4': 7.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 6,
#    'Hor_name': 'エクストラノート',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 478,
#    'Horse_weight_Flux': 6.0,
#    'Jockey': '丹内',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 98.6,
#    'Popularity': 11,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 106.9,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 5,
#    'Trainer_1': '美浦',
#    'Trainer_2': '伊藤圭',
#    'Uni_Num': 4,
#    'ato_3_F': 39.3,
#    'competition_count': 2,
#    'corner_rank_1': 6.0,
#    'corner_rank_2': 5.0,
#    'corner_rank_3': 3.0,
#    'corner_rank_4': 3.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 4,
#    'Hor_name': 'ミルキーハート',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 454,
#    'Horse_weight_Flux': 6.0,
#    'Jockey': '松田',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 21.8,
#    'Popularity': 6,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.0,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 6,
#    'Trainer_1': '美浦',
#    'Trainer_2': '牧',
#    'Uni_Num': 3,
#    'ato_3_F': 39.8,
#    'competition_count': 2,
#    'corner_rank_1': 1.0,
#    'corner_rank_2': 1.0,
#    'corner_rank_3': 1.0,
#    'corner_rank_4': 1.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 1,
#    'Hor_name': 'イデアイホマジョル',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 454,
#    'Horse_weight_Flux': 2.0,
#    'Jockey': '黛',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 20.8,
#    'Popularity': 5,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.3,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 7,
#    'Trainer_1': '美浦',
#    'Trainer_2': '和田雄',
#    'Uni_Num': 1,
#    'ato_3_F': 39.8,
#    'competition_count': 2,
#    'corner_rank_1': 6.0,
#    'corner_rank_2': 5.0,
#    'corner_rank_3': 3.0,
#    'corner_rank_4': 3.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 7,
#    'Hor_name': 'カワキタジャズ',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 534,
#    'Horse_weight_Flux': 6.0,
#    'Jockey': '池添',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 7.2,
#    'Popularity': 4,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.3,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 8,
#    'Trainer_1': '栗東',
#    'Trainer_2': '浜田',
#    'Uni_Num': 5,
#    'ato_3_F': 39.3,
#    'competition_count': 2,
#    'corner_rank_1': 10.0,
#    'corner_rank_2': 10.0,
#    'corner_rank_3': 8.0,
#    'corner_rank_4': 8.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 8,
#    'Hor_name': 'サトノトリガー',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 458,
#    'Horse_weight_Flux': 0.0,
#    'Jockey': '大野',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 5.1,
#    'Popularity': 3,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 107.5,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 9,
#    'Trainer_1': '美浦',
#    'Trainer_2': '高柳瑞',
#    'Uni_Num': 5,
#    'ato_3_F': 40.2,
#    'competition_count': 2,
#    'corner_rank_1': 2.0,
#    'corner_rank_2': 2.0,
#    'corner_rank_3': 2.0,
#    'corner_rank_4': 2.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 3,
#    'Hor_name': 'カシマホオズキ',
#    'Hor_sex_and_age': '牝3',
#    'Horse_weight': 436,
#    'Horse_weight_Flux': -4.0,
#    'Jockey': '秋山稔',
#    'JockeyWeight': 51.0,
#    'Odds_popularity': 33.2,
#    'Popularity': 8,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.0,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 10,
#    'Trainer_1': '美浦',
#    'Trainer_2': '加藤士',
#    'Uni_Num': 3,
#    'ato_3_F': 40.5,
#    'competition_count': 2,
#    'corner_rank_1': 3.0,
#    'corner_rank_2': 3.0,
#    'corner_rank_3': 3.0,
#    'corner_rank_4': 3.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 14,
#    'Hor_name': 'ローレルオルブラン',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 480,
#    'Horse_weight_Flux': -2.0,
#    'Jockey': '亀田',
#    'JockeyWeight': 54.0,
#    'Odds_popularity': 106.7,
#    'Popularity': 12,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.0,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 11,
#    'Trainer_1': '栗東',
#    'Trainer_2': '飯田雄',
#    'Uni_Num': 8,
#    'ato_3_F': 39.1,
#    'competition_count': 2,
#    'corner_rank_1': 10.0,
#    'corner_rank_2': 11.0,
#    'corner_rank_3': 12.0,
#    'corner_rank_4': 12.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   {'Hor_Num': 10,
#    'Hor_name': 'カフジジェミニ',
#    'Hor_sex_and_age': '牡3',
#    'Horse_weight': 514,
#    'Horse_weight_Flux': 12.0,
#    'Jockey': '水口',
#    'JockeyWeight': 56.0,
#    'Odds_popularity': 143.8,
#    'Popularity': 13,
#    'Race_Name': '3歳未勝利',
#    'Race_Time': 108.9,
#    'Race_date': 1597536000000.0,
#    'Race_id': 202001020204,
#    'Ranking': 12,
#    'Trainer_1': '栗東',
#    'Trainer_2': '湯窪',
#    'Uni_Num': 6,
#    'ato_3_F': 39.8,
#    'competition_count': 2,
#    'corner_rank_1': 14.0,
#    'corner_rank_2': 14.0,
#    'corner_rank_3': 13.0,
#    'corner_rank_4': 12.0,
#    'day_count': 2,
#    'field_condition': '重',
#    'field_length': 1700,
#    'field_type_1': 'ダ',
#    'field_type_2': '右',
#    'hadicap': '馬齢',
#    'horse_class': 'サラ系３歳',
#    'horse_class_2': '未勝利',
#    'number_of_hourses': 14,
#    'race_type': '[指]',
#    'start_time': 1125,
#    'target': 1,
#    'venue_area': '札幌',
#    'weather': '曇'},
#   ...],
#  'user': {'name': 'horse', 'password': 'race'}}

# %%
type(all_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Firebaseからデータを拾ってみる

# %%
import pyrebase

# %%
config = {
        "apiKey": "AIzaSyAwbn5Kn_APmjjbePcurULzaGqrqC46dsg",
        "authDomain": "horse-race-pred-firebase.firebaseapp.com",
        "databaseURL": "https://horse-race-pred-firebase-default-rtdb.asia-southeast1.firebasedatabase.app",
        "projectId": "horse-race-pred-firebase",
        "storageBucket": "horse-race-pred-firebase.appspot.com",
        "messagingSenderId": "77780114055",
        "appId": "1:77780114055:web:ccecc174cedfbc77b8f622",
        "measurementId": "G-Z71C5EXW6P"
        }
firebase = pyrebase.initialize_app(config)

# %%
db = firebase.database()

# %%
data = db.get()
data = data.val()
df = pd.DataFrame(data)

# %%
df
# Out:
#        Hor_Num   Hor_name Hor_sex_and_age  Horse_weight  Horse_weight_Flux  \
# 0           10    ラストサムライ              牡3           466                8.0
# 1           14    リュヌダムール              牝3           452               -2.0
# 2            3    ソニックムーヴ              牡3           488               -4.0
# 3           12  トランセンドパスト              牡3           460                4.0
# 4           16     バルネージュ              セ3           516               14.0
# ...        ...        ...             ...           ...                ...
# 39248        8    ダノンシュネラ              牝3           500               -4.0
# 39249       10   メイショウシャガ              牡4           512                2.0
# 39250        2   ブルーコンパクタ              牡5           474                4.0
# 39251        1     ルドンカズマ              牡4           496                0.0
# 39252        6     クリノカポネ              セ6           444               -6.0
#
#       Jockey  JockeyWeight  Odds_popularity  Popularity  Race_Name  ...  \
# 0         田辺          56.0              1.8           1      3歳未勝利  ...
# 1        小林凌          51.0              8.9           3      3歳未勝利  ...
# 2        木幡育          55.0             13.6           5      3歳未勝利  ...
# 3         宮崎          56.0             15.7           6      3歳未勝利  ...
# 4        木幡巧          56.0              9.0           4      3歳未勝利  ...
# ...      ...           ...              ...         ...        ...  ...
# 39248    岩田望          53.0              6.1           4  3歳以上2勝クラス  ...
# 39249     角田          54.0             94.6           9  3歳以上2勝クラス  ...
# 39250    和田竜          57.0             15.3           7  3歳以上2勝クラス  ...
# 39251     松若          57.0             10.8           6  3歳以上2勝クラス  ...
# 39252     酒井          57.0            140.5          10  3歳以上2勝クラス  ...
#
#        horse_class  horse_class_2  number_of_hourses  race_type start_time  \
# 0            サラ系３歳            未勝利                 16        (混)        955
# 1            サラ系３歳            未勝利                 16        (混)        955
# 2            サラ系３歳            未勝利                 16        (混)        955
# 3            サラ系３歳            未勝利                 16        (混)        955
# 4            サラ系３歳            未勝利                 16        (混)        955
# ...            ...            ...                ...        ...        ...
# 39248      サラ系３歳以上          ２勝クラス                 10        (混)       1610
# 39249      サラ系３歳以上          ２勝クラス                 10        (混)       1610
# 39250      サラ系３歳以上          ２勝クラス                 10        (混)       1610
# 39251      サラ系３歳以上          ２勝クラス                 10        (混)       1610
# 39252      サラ系３歳以上          ２勝クラス                 10        (混)       1610
#
#       target  venue_area  weather  corner_rank_3  corner_rank_4
# 0          0          中山        晴            NaN            NaN
# 1          0          中山        晴            NaN            NaN
# 2          0          中山        晴            NaN            NaN
# 3          1          中山        晴            NaN            NaN
# 4          1          中山        晴            NaN            NaN
# ...      ...         ...      ...            ...            ...
# 39248      1          阪神        晴            NaN            NaN
# 39249      1          阪神        晴            NaN            NaN
# 39250      1          阪神        晴            NaN            NaN
# 39251      1          阪神        晴            NaN            NaN
# 39252      1          阪神        晴            NaN            NaN
#
# [39253 rows x 37 columns]

# %%
df = df.sort_values(ascending=True,by=['Race_date','Race_id'])

# %%
df
# Out:
#        Hor_Num   Hor_name Hor_sex_and_age  Horse_weight  Horse_weight_Flux  \
# 0           10    ラストサムライ              牡3           466                8.0
# 1           14    リュヌダムール              牝3           452               -2.0
# 2            3    ソニックムーヴ              牡3           488               -4.0
# 3           12  トランセンドパスト              牡3           460                4.0
# 4           16     バルネージュ              セ3           516               14.0
# ...        ...        ...             ...           ...                ...
# 39248        8    ダノンシュネラ              牝3           500               -4.0
# 39249       10   メイショウシャガ              牡4           512                2.0
# 39250        2   ブルーコンパクタ              牡5           474                4.0
# 39251        1     ルドンカズマ              牡4           496                0.0
# 39252        6     クリノカポネ              セ6           444               -6.0
#
#       Jockey  JockeyWeight  Odds_popularity  Popularity  Race_Name  ...  \
# 0         田辺          56.0              1.8           1      3歳未勝利  ...
# 1        小林凌          51.0              8.9           3      3歳未勝利  ...
# 2        木幡育          55.0             13.6           5      3歳未勝利  ...
# 3         宮崎          56.0             15.7           6      3歳未勝利  ...
# 4        木幡巧          56.0              9.0           4      3歳未勝利  ...
# ...      ...           ...              ...         ...        ...  ...
# 39248    岩田望          53.0              6.1           4  3歳以上2勝クラス  ...
# 39249     角田          54.0             94.6           9  3歳以上2勝クラス  ...
# 39250    和田竜          57.0             15.3           7  3歳以上2勝クラス  ...
# 39251     松若          57.0             10.8           6  3歳以上2勝クラス  ...
# 39252     酒井          57.0            140.5          10  3歳以上2勝クラス  ...
#
#        horse_class  horse_class_2  number_of_hourses  race_type start_time  \
# 0            サラ系３歳            未勝利                 16        (混)        955
# 1            サラ系３歳            未勝利                 16        (混)        955
# 2            サラ系３歳            未勝利                 16        (混)        955
# 3            サラ系３歳            未勝利                 16        (混)        955
# 4            サラ系３歳            未勝利                 16        (混)        955
# ...            ...            ...                ...        ...        ...
# 39248      サラ系３歳以上          ２勝クラス                 10        (混)       1610
# 39249      サラ系３歳以上          ２勝クラス                 10        (混)       1610
# 39250      サラ系３歳以上          ２勝クラス                 10        (混)       1610
# 39251      サラ系３歳以上          ２勝クラス                 10        (混)       1610
# 39252      サラ系３歳以上          ２勝クラス                 10        (混)       1610
#
#       target  venue_area  weather  corner_rank_3  corner_rank_4
# 0          0          中山        晴            NaN            NaN
# 1          0          中山        晴            NaN            NaN
# 2          0          中山        晴            NaN            NaN
# 3          1          中山        晴            NaN            NaN
# 4          1          中山        晴            NaN            NaN
# ...      ...         ...      ...            ...            ...
# 39248      1          阪神        晴            NaN            NaN
# 39249      1          阪神        晴            NaN            NaN
# 39250      1          阪神        晴            NaN            NaN
# 39251      1          阪神        晴            NaN            NaN
# 39252      1          阪神        晴            NaN            NaN
#
# [39253 rows x 37 columns]

# %%
df.to_json('data.json',orient='records')

# %%
from model.main import MainData

# %%
MainData.save_to_db()
# Out:
# Updating firebase realtime database...
# All updates finished!!
# {'success': 'database updated'}

# %%
df = MainData.get_data()

# %%
df = scrape_train_data()
